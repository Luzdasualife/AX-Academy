# %% [markdown]
# ### Exemplo 1-1: size e position

# %%
import pyautogui
import time

pyautogui.click(100, 100)
time.sleep(2)  # Pausa a execução por 2s
pyautogui.write('Ola Mundo')

# %%
import pyautogui
# Define uma pausa de 1s
pyautogui.PAUSE = 1.0 

pyautogui.moveTo(100, 100) # Espera 1s
pyautogui.click()          # Espera 1s

# %%
# imprime a posição do mouse (várias vezes)

import pyautogui
import time

QTDE = 3
INTERVALO = 3

largura, altura = pyautogui.size()
print('Tela:', largura, 'x', altura)

time.sleep(INTERVALO)
i = 1
x, y = pyautogui.position()
print('Leitura', i, '-> Mouse em:', x, y)
while i < QTDE:
    print('Mova o mouse para outra posição em até',str(INTERVALO)+'s')
    time.sleep(INTERVALO)
    i += 1
    x, y = pyautogui.position()
    print('Leitura', i, '-> Mouse em:', x, y)
print('Fim.')
# Out:
# Tela: 1920 x 1080
# Leitura 1 -> Mouse em: 694 422
# Mova o mouse para outra posição em até 3s
# Leitura 2 -> Mouse em: 814 739
# Mova o mouse para outra posição em até 3s
# Leitura 3 -> Mouse em: 86 837
# Fim.

# %% [markdown]
# ### Exemplo 1-2: onScreen

# %%
# Verifica se um ponto está dentro ou fora da tela

import pyautogui
import time

largura, altura = pyautogui.size()
print(pyautogui.onScreen(10, 10))
time.sleep(1)
print(pyautogui.onScreen(-10, 10))
time.sleep(1)
print(pyautogui.onScreen(largura + 2, altura + 2))
time.sleep(1)
print(pyautogui.onScreen(500, 500))
# Out:
# True
# False
# False
# True

# %% [markdown]
# ### Exemplo 2-1: moveTo

# %%
# move mouse lentamente

import pyautogui
import time

pyautogui.moveTo(500, 500)
pyautogui.moveTo(300, 800, duration=2)
time.sleep(1)
pyautogui.moveTo(600, 200, duration=2)

# %% [markdown]
# ### Exemplo 2-2: move

# %%
# Faz movimentos do mouse relativos

import pyautogui

pyautogui.moveTo(800, 500, duration=2)
pyautogui.move(0, -200, duration=2)    # sobe 80
pyautogui.move(-200, 0, duration=2)    # esquerda 60
pyautogui.move(0, 200, duration=2)    # desce 100
pyautogui.move(200, 0, duration=2)    # direita 110

# %% [markdown]
# ### Exemplo 2-3: click e doubleClick

# %%
import pyautogui
import time

print('Posicione onde o mouse deve clicar em 3 segundos')
time.sleep(3)

pyautogui.click(430, 370)  # move e clica
time.sleep(2)
pyautogui.click(430, 460)  # move e clica
time.sleep(2)
pyautogui.click(430, 550)  # move e clica
time.sleep(2)
pyautogui.click(430, 550, button='right') # move e clique direito
time.sleep(2)
pyautogui.click(430, 600, button='right') # move e clique direito
time.sleep(2)
# Out:
# Posicione onde o mouse deve clicar em 3 segundos

# %% [markdown]
# ### Exemplo 2-4: mouseDown e mouseUp

# %%
import pyautogui
import time

print('Prepare-se em 3 segundos')
time.sleep(3)

pyautogui.moveTo(290, 360, duration=0.5)
pyautogui.mouseDown()                 # pressiona o mouse
pyautogui.move(250, 0, duration=0.5)  # arrasta segurando
pyautogui.mouseUp()
time.sleep(0.5)
# Out:
# Prepare-se em 3 segundos

# %% [markdown]
# ### Exemplo 2-5: dragTo/drag (arrastar o mouse)

# %%
import pyautogui
import time

print('Prepare-se em 3 segundos')
time.sleep(4)

# arrasta de forma absoluta
pyautogui.moveTo(290, 360, duration=0.5)
pyautogui.click()
pyautogui.dragTo(430, 460, duration=1, button='right')
# Out:
# Prepare-se em 3 segundos

# %% [markdown]
# ### Exemplo 2-6(a): scroll

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(5)

pyautogui.moveTo(200, 540)
time.sleep(0.2)
pyautogui.scroll(-400)  # rolagem para baixo
time.sleep(2)
pyautogui.scroll(400)   # rolagem para cima
time.sleep(2)
# Out:
# Você tem 3s para se preparar

# %% [markdown]
# ### Exemplo 2-6(b): vscroll

# %%
import pyautogui
import time

print("Scroll Vertical: Você tem 3s para você colocar o foco na janela certa")
time.sleep(3)

pyautogui.vscroll(200)
time.sleep(1)
pyautogui.vscroll(-300)
time.sleep(1)
# Out:
# Scroll Vertical: Você tem 3s para você colocar o foco na janela certa

# %% [markdown]
# ### Exemplo 2-6(c): hscroll

# %%
import pyautogui
import time

print("Scroll Horizontal: Você tem 3s para você colocar o foco na janela certa")
time.sleep(3)

pyautogui.hscroll(100)
time.sleep(1)
pyautogui.hscroll(-100)
time.sleep(1)
# Out:
# Scroll Horizontal: Você tem 3s para você colocar o foco na janela certa

# %% [markdown]
# ### Exemplo 3-1: Teclado - write

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(3)

pyautogui.write('ola, isso foi digitado pelo bot', interval=0.2)
pyautogui.press('enter')
# Out:
# Você tem 3s para se preparar

# %% [markdown]
# ### Exemplo 3-2: Teclado - tecla e lista de teclas

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(3)

pyautogui.moveTo(520, 360)
pyautogui.click()
pyautogui.press(['tab','tab', 'tab','tab', 'tab'])
time.sleep(2)
pyautogui.write('Arraial do Cabo')
time.sleep(2)
pyautogui.press('F1')
time.sleep(2)
# Out:
# Você tem 3s para se preparar

# %% [markdown]
# ### Exemplo 3-3: Teclado - keyDown e keyUp

# %%
import pyautogui
import time

magia = 100 

print("Você tem 3s para se preparar")
time.sleep(3)

pyautogui.moveTo(300, 360)
pyautogui.click()

for i in range(magia):
    pyautogui.hotkey('shift','a')
    pyautogui.write('bracadabra')
    pyautogui.press('space')
# Out:
# Você tem 3s para se preparar

# %% [markdown]
# ### Exemplo 3-4: Teclado - hold

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(4)

pyautogui.moveTo(300, 360)
pyautogui.click()
with pyautogui.hold('shift'):
    pyautogui.press(['a'])
# Out:
# Você tem 3s para se preparar

# %% [markdown]
# ### Exemplo 3-5: Teclado - hotkey

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(4)

pyautogui.moveTo(300, 360)
pyautogui.click()

pyautogui.hotkey('ctrl', 'a')  # selecionar tudo
time.sleep(2)
pyautogui.hotkey('ctrl', 'c')  # copiar
time.sleep(2)
pyautogui.press(['tab', 'tab', 'tab', 'tab'])
pyautogui.hotkey('ctrl', 'v')  # colar
time.sleep(4)
# Out:
# Você tem 3s para se preparar

# %% [markdown]
# ### Exemplo 4-1: Tela - screenshot

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(4)

# Salvar a tela inteira em arquivo
pyautogui.screenshot('tela.png')
time.sleep(2)

# Retornar a imagem (sem salvar)
img = pyautogui.screenshot()
print(type(img))
time.sleep(2)

# Capturar só uma região (x, y, largura, altura)
pyautogui.screenshot('canto.png', region=(0, 0, 400, 300))
# Out:
# Você tem 3s para se preparar
# <class 'PIL.Image.Image'>
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
#abrir a imagem em uma nova janela
from PIL import Image

img1 = Image.open('tela.png')
img1.show()

# %%
#abre a imagem do arquivo no notebook jupyter
from IPython.display import Image, display
display(Image(filename='tela.png'))

# %% [markdown]
# ### Exemplo 4-2: Tela - locateOnScreen e center

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(4)

try:
    box = pyautogui.locateOnScreen('calculadora.png', confidence=0.7)
    x, y = pyautogui.center(box)
    pyautogui.click(x, y)
    print('Cliquei na calculadora!')
except pyautogui.ImageNotFoundException:
    print('Nao achei a calculadora na tela.')
# Out:
# Você tem 3s para se preparar
# Cliquei na calculadora!

# %% [markdown]
# ### Exemplo 4-3: Tela - locateCenterOnScreen

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(4)

try:
    ponto = pyautogui.locateCenterOnScreen('calculadora.png', confidence=0.9)
    pyautogui.click(ponto)
    print('Cliquei no centro calculadora.')
except pyautogui.ImageNotFoundException:
    print('Não encontrei a calculadora na tela.')
# Out:
# Você tem 3s para se preparar
# Cliquei no centro calculadora.

# %% [markdown]
# ### Exemplo 4-4: Tela - locateAllOnScreen()

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(3)

try:
    # pega todas as ocorrências
    boxes = list(pyautogui.locateAllOnScreen('icone.png', confidence=0.90, grayscale=True))
    print('Quantidade encontrada:', len(boxes))

    for box in boxes:
        x, y = pyautogui.center(box)
        pyautogui.click(x, y)
        time.sleep(0.5)
        pyautogui.press('esc')
        time.sleep(0.2)
except pyautogui.ImageNotFoundException:
    print('Não encontrei nenhuma ocorrência.')
# Out:
# Você tem 3s para se preparar
# Quantidade encontrada: 12

# %% [markdown]
# ### Exemplo 4-5: Tela - pixel e pixelMatchesColor

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(3)

x, y = 430, 700
pyautogui.moveTo(x,y)
cor = pyautogui.pixel(x, y)  # cor vermelho
print('Cor em', x, y, ':', cor)
r, g, b = cor
print(f"\033[48;2;{r};{g};{b}m    \033[0m  <- cor capturada")

print(pyautogui.pixelMatchesColor(x, y, cor))

x, y = 655, 700
pyautogui.moveTo(x,y)
print(pyautogui.pixelMatchesColor(x, y, cor))

x, y = 790, 700
pyautogui.moveTo(x,y)
print(pyautogui.pixelMatchesColor(x, y, cor))

x, y = 1000, 700
pyautogui.moveTo(x,y)
print(pyautogui.pixelMatchesColor(x, y, cor))

x, y = 1220, 700
pyautogui.moveTo(x,y)
print(pyautogui.pixelMatchesColor(x, y, cor))
# Out:
# Você tem 3s para se preparar
# Cor em 430 700 : (43, 108, 255)
#       <- cor capturada
# True
# False
# False
# False
# True

# %% [markdown]
# ### Exemplo 5-1: Caixas de diálogo

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(3)

pyautogui.alert(text='Vou iniciar o bot agora.', title='RPA', button='OK')
resp = pyautogui.confirm(text='Continuar?', title='RPA', buttons=['Sim', 'Nao'])
print('Resposta:', resp)
# Out:
# Você tem 3s para se preparar
# Resposta: Sim
# 'OK'

# %% [markdown]
# ### Exemplo 5-2: interpolação (tweening)

# %%
import pyautogui
import time

pyautogui.FAILSAFE = True
pyautogui.PAUSE = 0.2

print("Você tem 3s para se preparar")
time.sleep(3)

pyautogui.moveTo(200, 400, duration=2)
time.sleep(1)
pyautogui.moveTo(500, 400, duration=4, tween=pyautogui.easeInQuad)
time.sleep(1)
pyautogui.moveTo(900, 400, duration=4, tween=pyautogui.easeOutQuad)
time.sleep(1)
pyautogui.moveTo(1200, 400, duration=4, tween=pyautogui.easeInBounce)
time.sleep(1)
pyautogui.moveTo(1500, 400, duration=2, tween=pyautogui.easeInElastic)
# Out:
# Você tem 3s para se preparar

# %% [markdown]
# ### Exemplo 5-3: Esperar imagem aparecer (com timeout)

# %%
import pyautogui
import time

print("Você tem 3s para se preparar")
time.sleep(3)

def esperar_imagem(arquivo, timeout=10, confidence=0.9):
    inicio = time.time()
    while True:
        try:
            box = pyautogui.locateOnScreen(arquivo, confidence=confidence)
            return box
        except pyautogui.ImageNotFoundException:
            pass

        if time.time() - inicio > timeout:
            return None

        time.sleep(0.3)

box = esperar_imagem('enviar_form.png', timeout=8)
if box is None:
    print('Nao apareceu. Vou tirar screenshot e parar.')
    pyautogui.screenshot('erro_login.png')
else:
    pyautogui.click(pyautogui.center(box))
    print('Cliquei no login.')
# Out:
# Você tem 3s para se preparar
# Nao apareceu. Vou tirar screenshot e parar.
